# %%
import sys 
sys.path.insert(0, '/Kiffya_10_acc/SolarStrategy-Insight/')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scripts.Moonlight_data_visualization import DataVisualization

# %%
data=pd.read_csv('../data/benin-malanville.csv')

# %%
dv=DataVisualization(data)

# %%
# Correlation Heatmap
solar_temp_cols = ['GHI', 'DNI', 'DHI', 'TModA', 'TModB']
dv.plot_correlation_heatmap(solar_temp_cols)

# %%
import scipy
# Columns related to wind conditions and solar irradiance
wind_cols = ['WS', 'WSgust', 'WD', 'GHI', 'DNI', 'DHI']

# Scatter Matrix for Wind Conditions and Solar Irradiance
dv.plot_scatter_matrix(wind_cols)

# %%
# Assuming 'df' is your DataFrame containing wind speed and direction data
dv.plot_wind_polar('WS', 'WD')
# dv.polar_plot('WS')

# %%
# ploting histograms for GHI, DNI, DHI, WS, TModA, and TModB
columns_to_plot = ['GHI', 'DNI', 'DHI', 'WS', 'TModA', 'TModB']
dv.histogram(columns_to_plot)

# %%
# Plot time series for solar variables
dv.plot_time_series(['GHI', 'DNI', 'DHI', 'Tamb'], 'Time Series of Solar Irradiance and Temperature', 'Values')

# %%
# Plot impact of cleaning on sensor readings
dv.plot_cleaning_impact(['ModA', 'ModB'])
